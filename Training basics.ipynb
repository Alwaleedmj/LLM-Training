# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
print(os.getenv('OPENAI_API_KEY'))
# Out:
# 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

# %%
os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY')

# %%
my_text = "Whats the comes after friday?"

# %%
from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage, AIMessage

chat = ChatOpenAI(temperature=0.7)

# %%
chat(
    [
        SystemMessage(content="You are expert in market research in food and beverage international market. You are a consultant for a company that wants to expand its business"),
        HumanMessage(content="I want to make beverage business in KSA, sugget for me 3 flavors"),
    ]
)
# Out:
# AIMessage(content='When considering flavors for your beverage business in KSA (Kingdom of Saudi Arabia), it is important to take into account the local preferences and cultural context. Here are three flavors that could be a good fit for the Saudi Arabian market:\n\n1. Arabic Coffee: Arabic coffee, also known as Qahwa, is an integral part of Saudi Arabian culture. It is a lightly spiced and aromatic coffee traditionally served in small cups. Developing a beverage that incorporates the flavors of Arabic coffee, such as cardamom and saffron, could be a unique and appealing option for the local market.\n\n2. Date and Almond: Dates are widely consumed in Saudi Arabia and play a significant role in the local cuisine. Combining the natural sweetness of dates with the nuttiness of almonds could create a refreshing and healthy beverage option. This flavor combination would cater to the local taste preferences while also providing a nutritious option.\n\n3. Mint and Lemon: Mint and lemon are 
# ...

# %%
from langchain.schema import Document

# %%
Document(page_content="This is my document. It is full of text that I've gathered from other places",
         metadata={
             'my_document_id' : 234234,
             'my_document_source' : "The LangChain Papers",
             'my_document_create_time' : 1680013019
         })
# Out:
# Document(page_content="This is my document. It is full of text that I've gathered from other places", metadata={'my_document_id': 234234, 'my_document_source': 'The LangChain Papers', 'my_document_create_time': 1680013019})

# %%
from langchain.embeddings import OpenAIEmbeddings
embeddings = OpenAIEmbeddings()

# %%
text = "Alwaleed"

# %%
text_embedding = embeddings.embed_query(text)
print (f"Here's a sample: {text_embedding[:5]}...")
print (f"Your embedding is length {len(text_embedding)}")
# Out:
# Here's a sample: [-0.00899238656830977, -0.011185818064569284, -0.003414852042802798, -0.023861256870686968, -0.025323545155741728]...
# Your embedding is length 1536

# %%
from langchain.llms import OpenAI
from langchain import PromptTemplate

llms = OpenAI(model_name="text-davinci-003")

# %%
prompt = """

1+1=3
"""

# %%
llms(prompt)
# Out:
# '\nNo, 1+1 equals 2.'

# %%
##Prompts template

# %%
template = """
I really want to travel to {location}. What should I do there?

Respond in one short sentence
"""

prompt = PromptTemplate(
    template=template,
    input_variables=["location"],
)

final_prompt = prompt.format(location="Rome")

print (f"Final Prompt: {final_prompt}")
print ("-----------")
print (f"LLM Output: {llms(final_prompt)}")
# Out:
# Final Prompt:
# I really want to travel to . What should I do there?
#
# Respond in one short sentence
#
# -----------
# LLM Output: Explore the culture, history, and cuisine of the destination!

# %%
## Data Loader

# %%
from langchain.document_loaders import HNLoader

# %%
loader = HNLoader("https://news.ycombinator.com/item?id=34422627")

# %%
from langchain.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.embeddings import OpenAIEmbeddings

# %%
loader = TextLoader("hrsd.txt")
document = loader.load()

# %%
print (f"Document: {document}")
# Out:
# Document: [Document(page_content='ماظن لمعلا\nرداصلا موسرملاب يكلملا مقر ( م51/ ) خيراتو 1426/08/23 ـه\nلدعملا موسرملاب يكلملا مقر ( م24/ ) خيراتو 1434/05/12 ـه\nلدعملا موسرملاب يكلملا مقر ( م1/ ) خيراتو 1435/01/22 ـه\nلدعملا موسرملاب يكلملا مقر ( م46/ ) خيراتو 1436/06/05 ـه\nلدعملا موسرملاب يكلملا ر مق ( م14/ ) خيراتو 1440/02/22 ــه\nلدعملا موسرملاب يكلملا مقر ( م134/ ) خيراتو 1440/11/27 ـه\nلدعملا موسرملاب يكلملا مقر ( م5/ ) خيراتو 1442/01/07 ـه\n2\nتايوتحملا\n بابلا لولأا : تافيرعتلا / ماكحلأا ةماعلا 4\n لصفلا لولأا / افيرعتلا ت 5\n لصفلا يناثلا / ماكحلأا ةماعلا 7\n بابلا يناثلا : يمظنت تايلمع فيظوتلا 14\n لصفلا لولأا / تادحو فيظوتلا 11\n لصفلا يناثلا / فيظوت نيقوعملا 12\n لصفلا ثلاثلا / ا بتاكمل ةيلهلأا فيظوتل ،نينطاوملا بتاكمو مادقتسلاا 13\n بابلا ثلاثلا : فيظوت يرغ نييدوعسلا 14\n بابلا عبارلا : بيردتلا ليهأتلاو 17\n لصفلا لولأا / بيردتلا ليهأتلاو ىدل بحاص لمعلا 18\n لصفلا يناثلا / دقع ليهأتلا بيردتلاو عم يرغ نيلماعلا ىدل بحاص لمعلا 19\n بابلا سماخلا : تاقلاع لمعلا 20\n لصفلا لو
# ...

# %%
# Splitting text
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
print (f"Text Splitter: {text_splitter}")
# Out:
# Text Splitter: <langchain.text_splitter.RecursiveCharacterTextSplitter object at 0x1467509d0>

# %%
# !pip install faiss-cpu
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 3.9 MB/s eta 0:00:00a 0:00:010m
# ...

# %%
texts = text_splitter.split_documents(document)
embeddings = OpenAIEmbeddings()
db = FAISS.from_documents(texts, embeddings)

# %%
retriever = db.as_retriever()

# %%
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'OpenAIEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x1468cb7f0>)

# %%
docs = retriever.get_relevant_documents("في حال ان الموظف حصل على اجازة سنوية ولم يستطع استخدامها بسبب ظروف العمل او الظروف الخاصة به فانه يحق له استخدامها في العام التالي")

# %%
print (f"Documents: {docs}")
# Out:
# Documents: [Document(page_content='ً بالإجازة بوقت كا ٍف لا يقل عن ثلاثين يوما\n.\nةداملا ةرشاعلا دعب ةئاملا :\nمنها إلى ةنسلا ةيلاتلا . ً .1 للعامل بموافقةصاحب العمل أن يؤجل إجازته السنوية أو أياما\n، فإذا اقتضـت فورظ ً .2 لصـاحب العمل حق تأجيل إجازة العامل بعد نهاية سـنة اسـتحقاقها إذا اقتضـت ظروف العمل ذلك لمدة لا تزيد على تسـعين يوما\nيتعدىالتأجيل نهاية السنة التالية لسنة ا قاقحتس ةزاجلإا . ّ العمل استمرار التأجيل وجب الحصول على موافقة العامل كتابة ، على ألا\nةداملا ةيداحلا ةرشع دعب ةئاملا :\nلماعلل قحلا يف لوصحلا ىلع ةرجأ نع مايأ ةزاجلإا ةقحتسملا اذإ كرت لمعلا لبق هلامعتسا اهل كلذو اب ةبسنل ىلإ ةدملا تيلا مل لصحي ىلع هتزاجإ اهنع امك\nقحتسي ةرجأ ةزاجلإا نع ءازجأ ةنسلا ةبسنب ام هاضق اهنم يف لمعلا .\nا ةدامل ةيناثلا ةرشع دعب ةئاملا :\nلكل لماع قحلا يف ةزاجإ رجأب لماك يف دايعلأا تابسانملاو تيلا اهددحت ةحئلالا .\nةداملا ةثلاثلا ةرشع دعب ةئاملا "35" :\nعم ةاـعارم تازاـجإ ةأرملا ةـلماـعلا ةددـحملا بـجومب اذـه ماـظنلا , لـماـعلل قحلا يف ةزاـجإ رجأـب لـماـك ةدـمل ةـــــسمخ ماـيأ يف اـح ة
# ...

# %%
print("\n\n".join([x.page_content[:200] for x in docs[:2]]))
# Out:
# ً بالإجازة بوقت كا ٍف لا يقل عن ثلاثين يوما
# .
# ةداملا ةرشاعلا دعب ةئاملا :
# منها إلى ةنسلا ةيلاتلا . ً .1 للعامل بموافقةصاحب العمل أن يؤجل إجازته السنوية أو أياما
# ، فإذا اقتضـت فورظ ً .2 لصـاحب العمل حق
#
# ا . ّ الفعلية . ويحرم العامل من أجر الإجازة إذا ثبت أنه لم يؤِد الامتحان ، مع عدم الإخلال بحقصاحب العمل في مساءلته تأديبي
# .2 اذإ مل لـــصحي لماعلا ىلع وم ةقفا بحاـــص لمعلا ىلع هباـــستنا ىلإ ةـــســـ
